# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/ext_day_mean_norm_4.csv")

# %%
import matplotlib.pyplot as plt

# Plot the last 4 columns
df.plot(subplots=True, figsize=(12, 6))
plt.tight_layout()
plt.show()
